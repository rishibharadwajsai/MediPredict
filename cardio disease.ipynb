# %%
import pandas as pd
import numpy as np
cols = ['Unnamed: 0', 'id', 'age', 'gender', 'height', 'weight', 'ap_hi','ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio']
df = pd.read_csv("health_data.csv",header=None,skiprows=1,names=cols)
df
# Out:
#        Unnamed: 0       id      age  gender  height  weight  ap_hi  ap_lo  \
# 0               0      0.0  18393.0       1   168.0    62.0  110.0   80.0
# 1               1      1.0  20228.0       0   156.0    85.0  140.0   90.0
# 2               2      2.0  18857.0       0   165.0    64.0  130.0   70.0
# 3               3      3.0  17623.0       1   169.0    82.0  150.0  100.0
# 4               4      4.0  17474.0       0   156.0    56.0  100.0   60.0
# ...           ...      ...      ...     ...     ...     ...    ...    ...
# 69995       69995  99993.0  19240.0       1   168.0    76.0  120.0   80.0
# 69996       69996  99995.0  22601.0       0   158.0   126.0  140.0   90.0
# 69997       69997  99996.0  19066.0       1   183.0   105.0  180.0   90.0
# 69998       69998  99998.0  22431.0       0   163.0    72.0  135.0   80.0
# 69999       69999  99999.0  20540.0       0   170.0    72.0  120.0   80.0
#
#        cholesterol  gluc  smoke  alco  active  cardio
# ...

# %%
df2 = df.drop(columns=['Unnamed: 0','id'])
df2.head()
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393.0       1   168.0    62.0  110.0   80.0            0     0      0
# 1  20228.0       0   156.0    85.0  140.0   90.0            2     0      0
# 2  18857.0       0   165.0    64.0  130.0   70.0            2     0      0
# 3  17623.0       1   169.0    82.0  150.0  100.0            0     0      0
# 4  17474.0       0   156.0    56.0  100.0   60.0            0     0      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df2['age'] = (df['age']/365.25).astype(int)
df2.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       1   168.0    62.0  110.0   80.0            0     0      0     0
# 1   55       0   156.0    85.0  140.0   90.0            2     0      0     0
# 2   51       0   165.0    64.0  130.0   70.0            2     0      0     0
# 3   48       1   169.0    82.0  150.0  100.0            0     0      0     0
# 4   47       0   156.0    56.0  100.0   60.0            0     0      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df2.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      52.803257      0.349571    164.359229     74.205690    128.817286
# std        6.762462      0.476838      8.210126     14.395757    154.011419
# min       29.000000      0.000000     55.000000     10.000000   -150.000000
# 25%       48.000000      0.000000    159.000000     65.000000    120.000000
# 50%       53.000000      0.000000    165.000000     72.000000    120.000000
# 75%       58.000000      1.000000    170.000000     82.000000    140.000000
# max       64.000000      1.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      0.366871      0.226457      0.088129      0.053771
# ...

# %%
df2['BMI'] = (df2['weight']/(df2['height']*df2['height']))*10000
df2.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       1   168.0    62.0  110.0   80.0            0     0      0     0
# 1   55       0   156.0    85.0  140.0   90.0            2     0      0     0
# 2   51       0   165.0    64.0  130.0   70.0            2     0      0     0
# 3   48       1   169.0    82.0  150.0  100.0            0     0      0     0
# 4   47       0   156.0    56.0  100.0   60.0            0     0      0     0
#
#    active  cardio        BMI
# 0       1       0  21.967120
# 1       1       1  34.927679
# 2       0       1  23.507805
# 3       1       1  28.710479
# 4       0       0  23.011177

# %% [markdown]
# # BMI Range
# - below 18.5 underweight
# - 18.5-24.9 healthy weight
# - 25-29.9 overweight
# - above30 obesity

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(df2['BMI'],bins=50,rwidth=0.85,log=True)
plt.title("BMI Range")
plt.xlabel("BMI value")
plt.ylabel("frequency")
plt.show()

# %%
# %matplotlib inline
df3 = df2[(df2['BMI']>10) & (df2['BMI']<50)]
plt.hist(df3['BMI'],bins=50,rwidth=0.85)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
correlation_matrix = df3.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %%
df3.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  69749.000000  69749.000000  69749.000000  69749.000000  69749.000000
# mean      52.801660      0.349984    164.447204     74.047538    128.793933
# std        6.762833      0.476968      7.872900     13.991006    154.281679
# min       29.000000      0.000000     98.000000     28.000000   -150.000000
# 25%       48.000000      0.000000    159.000000     65.000000    120.000000
# 50%       53.000000      0.000000    165.000000     72.000000    120.000000
# 75%       58.000000      1.000000    170.000000     82.000000    140.000000
# max       64.000000      1.000000    250.000000    180.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  69749.000000  69749.000000  69749.000000  69749.000000  69749.000000
# mean      96.561815      0.366299      0.225709      0.088245      0.053779
# ...

# %%
# %matplotlib inline
plt.hist(df3['ap_lo'],bins=50,rwidth=0.85,color="blue",log=True,label="ap_lo")
plt.hist(df3['ap_hi'],bins=50,rwidth=0.85,color="red",log=True,label="ap_hi")
plt.legend()
plt.title("ap_lo & ap_hi")
plt.xlabel("value")
plt.ylabel("freqency")
plt.show()

# %%
df4 = df3[(df3['ap_hi']<=300)]
df4 = df4[(df4['ap_lo'] <= df4['ap_hi']) & (df4['ap_lo']>10)]

# %%
# %matplotlib inline
correlation_matrix = df4.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation of variables ")
plt.show()

# %%
df4.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       1   168.0    62.0  110.0   80.0            0     0      0     0
# 1   55       0   156.0    85.0  140.0   90.0            2     0      0     0
# 2   51       0   165.0    64.0  130.0   70.0            2     0      0     0
# 3   48       1   169.0    82.0  150.0  100.0            0     0      0     0
# 4   47       0   156.0    56.0  100.0   60.0            0     0      0     0
#
#    active  cardio        BMI
# 0       1       0  21.967120
# 1       1       1  34.927679
# 2       0       1  23.507805
# 3       1       1  28.710479
# 4       0       0  23.011177

# %%
df4.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  68455.000000  68455.000000  68455.000000  68455.000000  68455.000000
# mean      52.789570      0.349032    164.447696     73.963376    126.640684
# std        6.764889      0.476668      7.855393     13.937256     16.675035
# min       29.000000      0.000000    120.000000     28.000000     24.000000
# 25%       48.000000      0.000000    159.000000     65.000000    120.000000
# 50%       53.000000      0.000000    165.000000     72.000000    120.000000
# 75%       58.000000      1.000000    170.000000     82.000000    140.000000
# max       64.000000      1.000000    250.000000    180.000000    240.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  68455.000000  68455.000000  68455.000000  68455.000000  68455.000000
# mean      81.272135      0.364020      0.224921      0.088043      0.053349
# ...

# %%
df4.cholesterol.unique()
# Out:
# array([0, 2, 1])

# %%
# df5 = df4.drop([(df4['cholesterol']==2) & (df4['ap_hi']>120) & (df4['cardio']==0)])
df6 = df4.drop(df4[(df4['cholesterol'] == 2) & (df4['cardio'] == 0)].index)
df6
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       1   168.0    62.0  110.0   80.0            0     0      0
# 1       55       0   156.0    85.0  140.0   90.0            2     0      0
# 2       51       0   165.0    64.0  130.0   70.0            2     0      0
# 3       48       1   169.0    82.0  150.0  100.0            0     0      0
# 4       47       0   156.0    56.0  100.0   60.0            0     0      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69994   57       0   165.0    80.0  150.0   80.0            0     0      0
# 69995   52       1   168.0    76.0  120.0   80.0            0     0      1
# 69997   52       1   183.0   105.0  180.0   90.0            2     0      0
# 69998   61       0   163.0    72.0  135.0   80.0            0     1      0
# 69999   56       0   170.0    72.0  120.0   80.0            1     0      0
#
#        alco  active  cardio        BMI
# ...

# %%
df6 = df6.drop(df4[(df4['cholesterol'] == 0) & (df4['cardio'] == 1)].index)
df6
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       1   168.0    62.0  110.0   80.0            0     0      0
# 1       55       0   156.0    85.0  140.0   90.0            2     0      0
# 2       51       0   165.0    64.0  130.0   70.0            2     0      0
# 4       47       0   156.0    56.0  100.0   60.0            0     0      0
# 5       59       0   151.0    67.0  120.0   80.0            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69988   60       0   160.0    59.0  110.0   70.0            0     0      0
# 69991   56       0   159.0    72.0  130.0   90.0            1     1      0
# 69995   52       1   168.0    76.0  120.0   80.0            0     0      1
# 69997   52       1   183.0   105.0  180.0   90.0            2     0      0
# 69999   56       0   170.0    72.0  120.0   80.0            1     0      0
#
#        alco  active  cardio        BMI
# ...

# %%
# %matplotlib inline
correlation_matrix = df6.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation matrix")
plt.show()

# %%
df6.gluc.unique()
# Out:
# array([0, 1, 2])

# %%
df7 = df6.drop(df6[(df['gluc']==2) & (df6['cardio']==0)].index)
df7
# Out:
# C:\Users\bvrvg\AppData\Local\Temp\ipykernel_21688\960729187.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df7 = df6.drop(df6[(df['gluc']==2) & (df6['cardio']==0)].index)
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       1   168.0    62.0  110.0   80.0            0     0      0
# 1       55       0   156.0    85.0  140.0   90.0            2     0      0
# 2       51       0   165.0    64.0  130.0   70.0            2     0      0
# 4       47       0   156.0    56.0  100.0   60.0            0     0      0
# 5       59       0   151.0    67.0  120.0   80.0            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69988   60       0   160.0    59.0  110.0   70.0            0     0      0
# 69991   56       0   159.0    72.0  130.0   90.0            1     1      0
# 69995   52       1   168.0    76.0  120.0   80.0            0     0      1
# ...

# %%
df7 = df7.drop(df7[(df7['gluc']==0) & (df7['cardio']==1)].index)

# %%
# %matplotlib inline
correlation_matrix = df7.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation matrix")
plt.show()

# %%
df7.shape
# Out:
# (36147, 13)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
score_RF = cross_val_score(RandomForestClassifier(),df7.drop(columns=['cardio']),df7['cardio'])
score_RF
# Out:
# array([0.97856155, 0.98049793, 0.98284687, 0.98021856, 0.98077189])

# %%
from sklearn.model_selection import train_test_split
X = df7.drop(columns=['cardio'])
Y = df7['cardio']
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.3,random_state=42)
rf_model = RandomForestClassifier()
rf_model.fit(X_train,y_train)
y_pred = rf_model.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9528
#            1       0.91      0.93      0.92      1317
#
#     accuracy                           0.98     10845
#    macro avg       0.95      0.96      0.96     10845
# weighted avg       0.98      0.98      0.98     10845

# %%
np.unique(df7,axis=0,return_counts=True)
# Out:
# (array([[ 29.        ,   0.        , 159.        , ...,   1.        ,
#            0.        ,  23.33768443],
#         [ 29.        ,   0.        , 175.        , ...,   1.        ,
#            0.        ,  19.26530612],
#         [ 29.        ,   1.        , 175.        , ...,   1.        ,
#            0.        ,  30.04081633],
#         ...,
#         [ 64.        ,   1.        , 185.        , ...,   1.        ,
#            0.        ,  26.00438276],
#         [ 64.        ,   1.        , 186.        , ...,   1.        ,
#            0.        ,  28.90507573],
#         [ 64.        ,   1.        , 188.        , ...,   1.        ,
#            0.        ,  22.91760978]]),
#  array([1, 1, 1, ..., 1, 1, 1]))

# %%
from sklearn.calibration import CalibratedClassifierCV
rf = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_rf = CalibratedClassifierCV(estimator=rf , method='sigmoid' , cv = 5)
classifier_rf.fit(X_train,y_train)
prob_pos = classifier_rf.predict_proba(X_test)
prob_pos
# Out:
# array([[0.99519874, 0.00480126],
#        [0.01155227, 0.98844773],
#        [0.99529897, 0.00470103],
#        ...,
#        [0.99529897, 0.00470103],
#        [0.99529897, 0.00470103],
#        [0.99529897, 0.00470103]])

# %%
prob_pos.shape
# Out:
# (10845, 2)

# %%
y_test
# Out:
# 27903    0
# 33131    1
# 24508    0
# 14178    1
# 34363    0
#         ..
# 56637    0
# 49614    0
# 47840    0
# 427      0
# 40599    0
# Name: cardio, Length: 10845, dtype: int64

# %%
y_test.shape
# Out:
# (10845,)

# %%
from sklearn.metrics import brier_score_loss , accuracy_score
brier_score = brier_score_loss(y_test == 1,prob_pos[:, 1])
accuracy = accuracy_score(y_test, classifier_rf.predict(X_test))
print(f'Brier Score: {brier_score}')
print(f'Accuracy: {accuracy}')
# Out:
# Brier Score: 0.013853453893025862
# Accuracy: 0.981005071461503

# %%
brier_score
# Out:
# np.float64(0.013853453893025862)

# %%
import joblib
# rf_model_2 = RandomForestClassifier()
# rf_model_2.fit(df7.drop(columns=['cardio']),df7['cardio'])
# joblib.dump(rf_model_2,'cardio_model_joblib')

# %%
df7.iloc[6].drop(columns=['cardio'])
# Out:
# age             61.000000
# gender           0.000000
# height         169.000000
# weight          80.000000
# ap_hi          120.000000
# ap_lo           80.000000
# cholesterol      0.000000
# gluc             0.000000
# smoke            0.000000
# alco             0.000000
# active           1.000000
# cardio           0.000000
# BMI             28.010224
# Name: 10, dtype: float64

# %%
mj = joblib.load('cardio_model_joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 mj = joblib.load('cardio_model_joblib')
#
# File ~\anaconda3\envs\Myenv2\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cardio_model_joblib'

# %%
input_data = np.array([61, 0, 169, 80, 120, 80, 0, 0, 0, 0,1, 28])
reshaped_input = input_data.reshape(1, -1)
pred = mj.predict(reshaped_input)
pred[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 input_data = np.array([61, 0, 169, 80, 120, 80, 0, 0, 0, 0,1, 28])
#       2 reshaped_input = input_data.reshape(1, -1)
# ----> 3 pred = mj.predict(reshaped_input)
#       4 pred[0]
#
# NameError: name 'mj' is not defined

# %%
classifier_rf.predict_proba(reshaped_input)
# Out:
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
X = df7[['age','ap_hi','ap_lo','cholesterol', 'gluc', 'BMI']]
Y = df7['cardio']
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.3,random_state=42)

# %%
rf2 = RandomForestClassifier(n_estimators=100,random_state=42)
classifier_rf2 = CalibratedClassifierCV(estimator=rf2 ,  method='sigmoid' , cv = 5)
classifier_rf2.fit(X_train,y_train)
prob_pos = classifier_rf2.predict_proba(X_test)
prob_pos
# Out:
# array([[0.99364819, 0.00635181],
#        [0.02237178, 0.97762822],
#        [0.99364819, 0.00635181],
#        ...,
#        [0.99364819, 0.00635181],
#        [0.99364819, 0.00635181],
#        [0.99364819, 0.00635181]])

# %%
brier_score2 = brier_score_loss(y_test == 1,prob_pos[:, 1])
accuracy2 = accuracy_score(y_test, classifier_rf.predict(X_test))
print(f'Brier Score: {brier_score2}')
print(f'Accuracy: {accuracy2}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 brier_score2 = brier_score_loss(y_test == 1,prob_pos[:, 1])
# ----> 2 accuracy2 = accuracy_score(y_test, classifier_rf.predict(X_test))
#       3 print(f'Brier Score: {brier_score2}')
#       4 print(f'Accuracy: {accuracy2}')
#
# File ~\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\calibration.py:507, in CalibratedClassifierCV.predict(self, X)
#     491 """Predict the target of new samples.
#     492
#     493 The predicted class is the class that has the highest probability,
#    (...)
#     504     The predicted class.
#     505 """
#     506 check_is_fitted(self)
# --> 507 return self.classes_[np.argmax(self.predict_proba(X), axis=1)]
#
# File ~\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\calibration.py:483, in CalibratedClassifierCV.predict_proba(self, X)
# ...

# %%
joblib.dump(classifier_rf2,'cardio_disease_prob')
# Out:
# ['cardio_disease_prob']

# %%
model = joblib.load('cardio_disease_prob')

# %%
X_test
# Out:
#        age  ap_hi  ap_lo  cholesterol  gluc        BMI
# 27903   61  130.0   90.0            0     0  31.640368
# 33131   56  120.0   80.0            2     2  24.464602
# 24508   52  120.0   80.0            0     0  24.977043
# 14178   59  160.0   90.0            2     2  36.390966
# 34363   56  120.0   80.0            0     0  27.099251
# ...    ...    ...    ...          ...   ...        ...
# 56637   45  120.0   80.0            0     0  30.116002
# 49614   58  120.0   80.0            1     1  27.055151
# 47840   47  120.0   70.0            0     0  27.434842
# 427     59  120.0   80.0            0     0  21.484375
# 40599   60  130.0   80.0            0     0  26.175195
#
# [10845 rows x 6 columns]

# %%
y_test
# Out:
# 27903    0
# 33131    1
# 24508    0
# 14178    1
# 34363    0
#         ..
# 56637    0
# 49614    0
# 47840    0
# 427      0
# 40599    0
# Name: cardio, Length: 10845, dtype: int64

# %%
model.predict_proba([[58,120,80,0,0,30.11]])
# Out:
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\bvrvg\anaconda3\envs\Myenv2\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
import seaborn as sns
sns.pairplot(df7[['age', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'cardio','BMI']], hue='cardio',palette='Set2')
# Out:
# C:\Users\bvrvg\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
